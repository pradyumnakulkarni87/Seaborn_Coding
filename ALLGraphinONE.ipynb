# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Draw a line
var1=np.array([0,20])
var2=np.array([0,40])
plt.plot(var1,var2)
plt.show()

# %% [raw]
# Plotting x and y points
# The plot() function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %%
#Draw a line in a diagram from position (1, 3) to position (8, 10)
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
#for only plotting points without line
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %% [raw]
# Multiple Points
# You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %%
# Example
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10)
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %% [raw]
# Default X-Points
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
ypoints=np.array([3,8,1,10,4,6])
plt.plot(ypoints)
plt.show()

# %% [raw]
# Markers
# You can use the keyword argument marker to emphasize each point with a specified marker:

# %%
#marker can be given as 'o'	Circle	
# '*'	Star	
# '.'	Point	
# ','	Pixel	
# 'x'	X	
# 'X'	X (filled)	
# '+'	Plus	
# 'P'	Plus (filled)	
# 's'	Square	
# 'D'	Diamond	
# 'd'	Diamond (thin)	
# 'p'	Pentagon	
# 'H'	Hexagon	
# 'h'	Hexagon	
# 'v'	Triangle Down	
# '^'	Triangle Up	
# '<'	Triangle Left	
# '>'	Triangle Right	
# '1'	Tri Down	
# '2'	Tri Up	
# '3'	Tri Left	
# '4'	Tri Right	
# '|'	Vline	
# '_'	Hline
ypoints=np.array([3,8,2,10,4,6])
plt.plot(ypoints,marker='D')
plt.grid()
plt.show()

# %% [raw]
# Line Reference
# Line Syntax	Description
# '-'	Solid line
# ':'	Dotted line
# '--'	Dashed line
# '-.'	Dashed/dotted line
#
# # specify line color ,line style and line width
# Line Styles
# You can choose any of these styles:
#
# Style	Or
# 'solid' (default)	'-'
# 'dotted'	':'
# 'dashed'	'--'
# 'dashdot'	'-.'
# 'None'	'' or ' '
#
# #Color Reference
# Color Syntax	Description
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White
#
# Line width consider as 10

# %%
ypoints=np.array([3,1,6,3,6,2])
plt.figure(dpi=100)
plt.plot(ypoints,marker='o',linestyle='dashed',color='orange',lw=5)
plt.show()

# %% [raw]
# MarkerSize
# Marker Size
# You can use the keyword argument markersize or the shorter version, ms to set the size of the markers:
#
# Example
# Set the size of the markers to 15

# %%
ypoints=np.array([3,1,6,3,6,2])
plt.plot(ypoints, marker = 'o', ms = 15)
plt.show()

# %% [raw]
# Marker Color
# You can use the keyword argument markeredgecolor or the shorter mec to set the color of the edge of the markers:
#
# Example
# Set the EDGE color to red

# %%
ypoints=np.array([3,1,6,3,6,2])
plt.plot(ypoints, marker = 'o', ms = 20,mec='red')
plt.show()

# %%
# You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# Example
# Set the FACE color to red:

ypoints=np.array([3,1,6,3,6,2])
plt.plot(ypoints, marker = 'o', ms = 20,mec='red',mfc='k')
plt.show()

# %%
# Using hexadecimal values as a color
# You can also use Hexadecimal color values
#3efd7c

ypoints=np.array([3,1,6,3,6,2])
plt.plot(ypoints, marker = 'o', ms = 20,mec='#3efd7c',mfc='#3efd7c')
plt.show()

# %% [markdown]
# # # MUltiple lines

# %%
data1=[1,3,5,6,7,9,4,7,1]
data2=[3,4,7,4,5,6,4,2,8]
plt.plot(data1,color='r',marker='o',lw=2.5,mfc='black',ms=12)
plt.plot(data2,color='m',marker='s',ls='dashed',lw=3.5,ms=15)
plt.grid()
plt.show()

# %%
#when both the axis values are given and we need to plot multiple lines

data1=[1,3,5,6,7,9,4,7,1]
data11=[2,4,6,8,10,12,14,16,18]
data2=[3,4,7,4,5,6,4,2,8]
data22=[1,2,3,8,10,12,14,16,20]
plt.figure(figsize=(10,5),dpi=100)
plt.plot(data11,data1,color='r',marker='o',lw=2.5,mfc='black',ms=12)
plt.plot(data22,data2,color='c',marker='s',ls='dashed',lw=3.5,ms=15)
plt.grid()
plt.show()

# %% [markdown]
# # Matplotlib Labels and Title

# %% [raw]
# Create Labels for a Plot
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.
# We can specifiy alignment of title as left right center default is center
# Set Font Properties for Title and Labels
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
# X: independant
days = [1,2,3,4,5,6,7]
#Y: dependant
cases = [10,50,5,60,15,30,20]

plt.plot(days,cases)
font1 = {'family':'serif','color':'blue','size':12}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("WEEKELY COVID CASES",loc='right',fontdict=font1)
plt.xlabel("DAYS",fontdict=font1)
plt.ylabel("CASES",fontdict=font2)
plt.show()

# %% [raw]
#    USING GRID

# %%
plt.plot(days,cases)
plt.xlabel("DAYS")
plt.ylabel("CASES")
plt.grid(axis='y',color = 'red', linestyle = '--', linewidth = 1.5)
plt.show()

# %%
plt.plot(days,cases)
plt.xlabel("DAYS")
plt.ylabel("CASES")
plt.grid(axis='x',color = 'green', linestyle = '--', linewidth = 2.5)
plt.show()

# %%
plt.plot(days,cases)
plt.xlabel("DAYS")
plt.ylabel("CASES")
plt.grid(color = 'red', linestyle = 'dotted', linewidth = 1.5)
plt.show()

# %% [markdown]
# # SUBPLOTS
#
# The subplots() Function
# The subplots() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.
#
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.
# So, if we want a figure with 2 rows an 1 column (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title("plot1")
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.title("hello")
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title("plot5")
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.title("2nd3rdcolplot6")

plt.suptitle("ALL SUBPLOTS")
plt.show()

# %% [markdown]
# # SCATTER PLOT

# %% [raw]
# Creating Scatter Plots
# With Pyplot, you can use the scatter() function to draw a scatter plot.
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
x=np.array([1,2,3,4,5,6,7])
y=np.array([86,64,13,24,75,36,71])
plt.scatter(x,y,marker='D',color='r',s=100)

x1=np.array([1,2,3,4,5,6,7])
y1=np.array([30,22,33,44,55,66,77])
color=np.array(['red','green','y','m','k','hotpink','orange'])

plt.scatter(x1,y1,color=color,alpha=0.5,s=200)
plt.colorbar()
plt.show()
plt.savefig(fname='ee.jpg',dpi=300)

# %% [markdown]
# # BAR & BARH PLOT

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color='r',width=0.2,align='edge')
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y,height=0.5)
plt.show()

# %% [markdown]
# # Matplotlib Histograms

# %% [raw]
# Histogram
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.
#
# Example: Say you ask for the height of 250 people, you might end up with a histogram like this:

# %% [raw]
# You can read from the histogram that there are approximately:
#
# 2 people from 140 to 145cm
# 5 people from 145 to 150cm
# 10 people from 151 to 156cm
# 7 people from 157 to 162cm
# 3 people from 185 to 190cm
# 1 people from 190 to 195cm

# %%
x=[141,144,146,146,148,149,150,152,153,153,153,154,154,154,155,151,160,160,158,161,161,159,160,187,188,189,192,170,175,182,165]

# %%
plt.hist(x,bins=[140,145,150,155,162,185,190,195],color='pink')
plt.grid()
plt.legend('xx')
plt.show()

# %% [markdown]
# # PIE Plot
# Note: The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#
# The value divided by the sum of all values: x/sum(x)
# (element/sum of element)

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
# Labels
# Add labels to the pie chart with the label parameter.

# The label parameter must be an array with one label for each wedge:

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
#Start the first wedge at 90 degrees:
plt.pie(y, labels = mylabels,startangle = 90)
plt.show()

# %%
#Pull the "Apples" wedge 0.2 from the center of the pie:
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#Add a shadow:
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
# Colors
# You can set the color of each wedge with the colors parameter.

# The colors parameter, if specified, must be an array with one value for each wedge:
# 'r' - Red
# 'g' - Green
# 'b' - Blue
# 'c' - Cyan
# 'm' - Magenta
# 'y' - Yellow
# 'k' - Black
# 'w' - White

mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
# Legend
# To add a list of explanation for each wedge, use the legend() function:
# Add a legend with a header:
plt.figure(figsize=(10,50))
plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend(title = "Four Fruits:",loc='upper right')
plt.show()
